# %%
numero_do_usuario = int(input("Digite um número: "))
if numero_do_usuario > 0:
    print("Seu número é positivo")
# Out:
# Digite sua número:  18
# Seu número é positivo

# %%
idade_do_usuario = int(input("Digite sua idade: "))
if idade_do_usuario >= 18:
    print("Você é maior de idade")
# Out:
# Digite sua idade:  18
# Você é maior de idade

# %%
numero_do_usuario = int(input("Digite um numero: "))
if numero_do_usuario >= 10:
    print("Número maior que 10")
# Out:
# Digite um numero:  12930713
# Número maior que 10

# %%
n1 = int(input("Digite um número: "))
if n1 %2 == 0:
    print("Seu número é par")
else:
    print("Seu número é ímpar")
# Out:
# Digite um número:  10
# Seu número é par

# %%
n1 = int(input("Qual a sua nota: "))
if n1 >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Qual a sua nota:  6
# Reprovado

# %%
n1 = int(input("Digite um numero: "))
n2 = int(input("∕nDigite um numero: "))
if n1 > n2:
    print("N1 é maior")
else:
    print("N2 é maior")
# Out:
# Digite um numero:  123
# ∕nDigite um numero:  124
# N2 é maior

# %%
n1 = int(input("Digite sua idade: "))
if n1 <= 12:
    print("Você é uma criança")
elif n1 <= 17:
    print("Você é um adolescente")
else:
    print("Você é adulto")
# Out:
# Digite sua idade:  17
# Você é um adolescente

# %%
n1 = int(input("Digite sua nota: "))

if n1 >= 7:
    print("Aluno Aprovado")
    
elif n1 >= 5:
    print("Aluno de recuperação")
    
else:
    print("Aluno Reprovado")
# Out:
# Digite sua nota:  5
# Aluno de recuperação

# %%
n1 = int(input("Digite sua nota: "))
n2 = int(input("∕nDigite outro numero: "))
n3 = int(input("∕nDigite outro numero: "))
if n1 > n2 and n3:
    print("N1 é maior que todos")
elif n2 > n1 and n3:
    print("N2 é o maior")
elif n3 > n2 and n1:
    print("n3 é o maior")
else:
    print("Os numeros são iguais")
# Out:
# Digite sua nota:  12
# ∕nDigite outro numero:  12
# ∕nDigite outro numero:  12
# Os numeros são iguais

# %%
usuario = "João"
senha = 9911

login_usuario = str(input("Digite seu nome: "))
login_senha = int(input("Digite sua senha: "))
if login_usuario == usuario and login_senha == senha:
    print("Login realizado com sucesso")
else:
    print("Login ou senha incorretos")
# Out:
# Digite seu nome:  abra
# Digite sua senha:  1234
# Login ou senha incorretos

# %%
n1 = int(input("Digite um numero: "))
if n1 >=1:
    print("Numero positivo")
elif n1 == 0:
    print("O numero é zero")
else:
    print("Numero negativo")
# Out:
# Digite um numero:  -1
# Numero negativo
