# %%
a = "Estou aprendendo a usar python"
print(a)
# Out:
# Estou aprendendo a usar python

# %%
j = "Meu nome é João"
g = "Eu moro em Goiânia"
print(j)
print(g)
# Out:
# Meu nome é João
# Eu moro em Goiânia

# %%
nome = "joao"
idade = "18"
print("meu nome é", nome, "e tenho", idade, " anos")
# Out:
# meu nome é joao e tenho 18  anos

# %%
cidade = "Goiânia"
estado = "GO"
pais = "Brasil"
print("Eu moro em", cidade, "-", estado, ",", pais)
# Out:
# Eu moro em Goiânia - GO , Brasil
